# %%
import os
import numpy as np
from custom_unet import CustomUNet
# Out:
# 2025-06-19 19:02:19.858738: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-19 19:02:19.879583: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750374139.901880 1676719 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750374139.908601 1676719 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1750374139.925914 1676719 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750374139.925948 1676719 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750374139.925951 1676719 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750374139.925953 1676719 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-19 19:02:19.931609: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/a.kanamarlapudi001/miniconda3/envs/tf_gpu_env/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
# Paths
test_image_folder = "/hpcstor6/scratch01/a/a.kanamarlapudi001/datasets/splits/test/images"
test_mask_folder  = "/hpcstor6/scratch01/a/a.kanamarlapudi001/datasets/splits/test/masks"
model_weights_path = "/hpcstor6/scratch01/a/a.kanamarlapudi001/datasets/model_weights_100.weights.h5"

# %%
# Load UNet and weights
unet = CustomUNet(
    img_height=512,
    img_width=512,
    batch_size=8,
    train_image_dir=None,
    train_mask_dir=None,
    val_image_dir=None,
    val_mask_dir=None,
    test_image_dir=test_image_folder,
    test_mask_dir=test_mask_folder,
    save_model_path=model_weights_path,
)

unet.model.load_weights(model_weights_path)
print("✅ Model weights loaded!")
# Out:
# 2025-06-19 18:26:33.698261: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_SYSTEM_DRIVER_MISMATCH: system has unsupported display driver / cuda driver combination
# ✅ Model weights loaded!

# %%
unet.visualize_predictions(num_images=100)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/291 [00:00<?, ?it/s]
