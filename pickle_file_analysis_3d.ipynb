# %%
import pickle
from pathlib import Path

# %%
pkl = Path("release_to_dicom_mapping_3d.pkl")

# %%
mapping = pickle.load(open(pkl, "rb"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mapping = pickle.load(open(pkl, "rb"))
#
# File ~/miniconda3/envs/tf_gpu_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'release_to_dicom_mapping_3d.pkl'

# %%
len(mapping)

# %%
list(mapping.items())[0]

# %%
list(mapping.items())[:5]

# %%
list(mapping.items())[-5:]

# %% [markdown]
# First 5 — sorted by release_id

# %%
list(sorted(mapping.items()))[:5]

# %% [markdown]
# last 5 — sorted by release_id

# %%
list(sorted(mapping.items()))[-5:]

# %%
mapping["2.25.100003998065499037342635672099403856296"]

# %%
mapping["2.25.100007943187352100893332332748172957450"]

# %%
mapping["2.25.100019041147446201791608259120993279"]

# %%
mapping["2.25.99999129600947434141962746676882710509"]

# %%
mapping["2.25.99999942832642861303111490353017157672"]
