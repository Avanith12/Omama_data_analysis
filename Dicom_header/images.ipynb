# %%
import numpy as np, matplotlib.pyplot as plt

# %%
A = np.load('/raid/mpsych/OMAMA/DATA/data/3d/images/2.25.303752069057352316286604420537828606550.npz')['data']

# %%
A.shape
# Out:
# (56, 2457, 1890)

# %%
plt.imshow(v[28], cmap='gray')

# %%
B = np.load('/raid/mpsych/OMAMA/DATA/data/2d_resized_1024/images/175866347207907406506251265978274611873.npz')['data']

# %%
B.shape
# Out:
# (1024, 1024)

# %%
plt.imshow(B, cmap='gray')
