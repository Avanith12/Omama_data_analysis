# %%
import omama as O

# %%
print(O)
# Out:
# <module 'omama' from '/home/a.kanamarlapudi001/projects/omama-proj/omama/__init__.py'>

# %%
print(dir(O))
# Out:
# ['Algorithms', 'ConfusionMatrix', 'Data', 'DataHelper', 'DataLoader', 'DeepSight', 'DeepSightPost', 'Features', 'Image', 'Normalize', 'O', 'OmamaLoader', 'Scanner', 'SimpleNamespace', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'algorithms', 'analysis', 'confusion_matrix', 'data', 'data_helper', 'deep_sight', 'dicom', 'feature_extractor', 'features', 'glob', 'helpers', 'io', 'loaders', 'mpl', 'normalizations', 'np', 'omama', 'os', 'pickle', 'plt', 'scanner', 'slurm_job_files', 'time']

# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
def safe_init_labels(cls, timing=False):#this is the code that i modified and checked 
    for i, path in enumerate(cls._image_paths):
        label = cls._labels.get(i)
        if label is None:
            print(f"Warning: Missing label for index {i}. Using default label 0.")
            label = 0
            cls._labels[i] = label
    print("Labels initialized safely.")

O.Data._init_labels = classmethod(safe_init_labels)

imgs = O.DataHelper.get2D(N=2, randomize=True, timing=True)
# Out:
# Loading config data from ini file
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>
# Labels initialized safely.
# get2D                    ...took     2.536704 seconds

# %%
imgs = O.DataHelper.get2D(N=2, randomize=True, timing=True)#this is the error i got previously
# Out:
# Loading config data from ini file
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2779738/2543086452.py in <module>
# ----> 1 imgs = O.DataHelper.get2D(N=2, randomize=True, timing=True)
#
# ~/projects/omama-proj/omama/helpers/data_helper.py in get2D(N, data_loader, cancer, randomize, config_num, timing)
#     301         else:
#     302             data_loader = data_loader
# --> 303         data = O.Data(data_loader, load_cache=True)
#     304         if cancer is True:
#     305             label = "IndexCancer"
#
# ~/projects/omama-proj/omama/data.py in __new__(cls, data_loader, cache, load_cache, cache_paths, print_data, timing)
#     112             print("DataLoader type is: ", type(cls.dl))
#     113             # initialize the data
# --> 114             cls._init(timing=timing)
# ...

# %%
print(O)
# Out:
# <module 'omama' from '/home/a.kanamarlapudi001/projects/omama-proj/omama/__init__.py'>

# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O
imgs = O.DataHelper.get2D(N=2, randomize=True, timing=True)#the same code works fine when i checked recently again
# Out:
# Loading config data from ini file
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>
# Labels initialized safely.
# get2D                    ...took     2.576354 seconds

# %%
imgs3d = O.DataHelper.get3D(N=2, cancer=True, randomize=True, timing=True)
# Out:
# Loading config data from ini file
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>
# Labels initialized safely.
# get3D                    ...took    34.499692 seconds

# %%
imgs[0]
# Out:
# namespace(filePath='/raid/data01/deephealth/dh_dcm_ast/2.25.219084228376144088111884490919912380795/DXm.2.25.162176646546723075484288017662937365482',
#           SOPInstanceUID='2.25.162176646546723075484288017662937365482',
#           StudyInstanceUID='2.25.219084228376144088111884490919912380795',
#           PatientID='DHS7X3OR2RBH',
#           InstanceNumber="3",
#           label='NonCancer',
#           imageLaterality='R',
#           shape=(3062, 2394),
#           metadata=None,
#           pixels=array([[1920, 1919, 1919, ..., 2660, 2635, 2644],
#                         [1920, 1921, 1922, ..., 2593, 2628, 2652],
#                         [1926, 1928, 1926, ..., 2613, 2660, 2683],
#                         ...,
#                         [ 661,  619,  577, ...,  394,  389,  389],
#                         [ 686,  644,  597, ...,  393,  390,  387],
#                         [ 723,  670,  615, ...,  393,  389,  391]], dtype=uint16))

# %%
import omama as O#was checking to see if get2D API works with raw data or pre-filtered data.

# List all attributes of DataHelper to see what's available
print(dir(O.DataHelper))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_add_bounding_box', '_get_coords', '_rescale_image', 'add_b_to_a', 'build_gt', 'check_data_instance', 'check_type', 'combine_best_results_and_resave', 'data_to_binary_bin_hists', 'file_to_list', 'get', 'get2D', 'get3D', 'get_files_in_collection', 'get_pixels', 'grid_view', 'image_collection_to_npy_file', 'list_to_caselist', 'merge_lists', 'namespaces_to_dict', 'parse_sop_uid_from_paths', 'read', 'remove_b_from_a', 'show_histogram', 'store', 'store_all', 'view', 'view_grid']

# %%
import inspect
print(inspect.getsource(O.DataHelper.get2D))
# Out:
#     @staticmethod
#     def get2D(
#         N=1, data_loader=None, cancer=None, randomize=False, config_num=2, timing=False
#     ):
#         """Returns a list of N random 2D images from the dataset.
#         Parameters
#         ----------
#         N : int
#             (default is 1) Number of images to return
#         data_loader : DataLoader
#             (default is None) The data loader to use to load the data
#         cancer : bool
#             (default is False)
#             If true will return only cancerous images, else will return only
#              non-cancerous images
#         randomize : bool
#             (default is False)
#             If true will return the images in a random order
#         config_num : int
#             (default is 1)
#             The option number corresponds to a set of paths to specific data
#             which is loaded into the data instance. config_num options are:
#             1: Full Omama dataset
# ...

# %%
import inspect
print(inspect.getsource(O.Data))
# Out:
# class Data:
#     """Singleton Data class used to represent and explore dicom data
#
#     Attributes
#     ----------
#     total_2d_noncancer : int
#         total number of 2D dicoms with a label of NonCancer
#     total_2d_cancer : int
#         total number of 2D dicoms with a label of IndexCancer
#     total_2d_preindex : int
#         total number of 3D dicoms with a label of PreIndexCancer
#     total_3d_noncancer : int
#         total number of 3D dicoms with a label of NonCancer
#     total_3d_cancer : int
#         total number of 3D dicoms with a label of IndexCancer
#     total_3d_preindex : int
#         total number of 3D dicoms with a label of PreIndexCancer
#     """
#
#     dl = None  # DataLoader object
#     # total number of 2D dicoms with a label of NonCancer
#     total_2d_noncancer = 0
#     # total number of 2D dicoms with a label of IndexCancer
#     total_2d_cancer = 0
#     # total number of 3D dicoms with a label of PreIndexCancer
# ...

# %%
# Check total images before calling get2D
data = O.Data(O.OmamaLoader(config_num=2), load_cache=True)
print(f"Total images available: {len(data._image_paths)}")

# Check if filtering flags exist (indicates previous filtering)
print("Filtered flags:", data._filtered_flags)

# Call get2D and compare
imgs = O.DataHelper.get2D(N=2, randomize=True, timing=True)
print(f"Images returned by get2D: {len(imgs)}")
# Out:
# Loading config data from ini file
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>
# Labels initialized safely.
# Total images available: 176492
# Filtered flags: {}
# Loading config data from ini file
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>
# Labels initialized safely.
# get2D                    ...took     2.055601 seconds
# Images returned by get2D: 2
