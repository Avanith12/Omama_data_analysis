# %%
import json

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# %%
img = np.load(
    "/hpcstor6/scratch01/a/a.kanamarlapudi001/HQ_StudyLevel_Data/original_studylevel/images/2.25.114636451652613361168646589101988366704/2.25.290339949723526955147035839643177131600.npz"
)["data"]
img.shape
# Out:
# (3062, 2394)

# %%
meta = json.loads(open(
    "/hpcstor6/scratch01/a/a.kanamarlapudi001/HQ_StudyLevel_Data/original_studylevel/metadata/2.25.114636451652613361168646589101988366704/2.25.290339949723526955147035839643177131600.json"
).read())
meta
# Out:
# {'PatientID': 'DH53FZPEIBFT',
#  'View': 'cranio-caudal',
#  'WindowCenter': [2875.0, 2929.0, 2785.0],
#  'WindowWidth': [900.0, 750.0, 1050.0],
#  'WindowCenterWidthExplanation': ['NORMAL', 'HARDER', 'SOFTER'],
#  'ImagerPixelSpacing': [0.09409090909091, 0.09409090909091],
#  'ImageLaterality': 'R',
#  'label': 'PreIndexCancer',
#  'coords': [922.0, 992.0, 1205.0, 1276.0],
#  'score': 0.19047486782073975}

# %%
coords = meta["coords"]
coords
# Out:
# [922.0, 992.0, 1205.0, 1276.0]

# %%
x1, y1, x2, y2 = coords
fig, ax = plt.subplots()
ax.imshow(img, cmap="gray")
ax.add_patch(Rectangle((x1, y1), x2 - x1, y2 - y1, fill=False, edgecolor="r", lw=2))
plt.show()
