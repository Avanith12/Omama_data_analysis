# %%
from pathlib import Path
import json

import numpy as np
import matplotlib.pyplot as plt

# %%
ROOT = Path("/hpcstor6/scratch01/a/a.kanamarlapudi001/2d_resized_256_uint16")
IMG_DIR = ROOT / "images"
META_DIR = ROOT / "metadata"

# %%
files = sorted(IMG_DIR.glob("*.npz"))
len(files), files[:3]
# Out:
# (163568,
#  [PosixPath('/hpcstor6/scratch01/a/a.kanamarlapudi001/2d_resized_256_uint16/images/100000039159562031368112550794429920461.npz'),
#   PosixPath('/hpcstor6/scratch01/a/a.kanamarlapudi001/2d_resized_256_uint16/images/100000201190603337191863609201535272336.npz'),
#   PosixPath('/hpcstor6/scratch01/a/a.kanamarlapudi001/2d_resized_256_uint16/images/100001062780186333300160449315992055513.npz')])

# %%
img0 = np.load(files[0])["data"]
print(files[0].name, img0.shape, img0.dtype)
# Out:
# 100000039159562031368112550794429920461.npz (256, 256) uint16

# %%
plt.imshow(img0, cmap="gray")
plt.title(files[0].name)
plt.show()

# %%
img1 = np.load(files[1])["data"]
print(files[1].name, img1.shape, img1.dtype)
# Out:
# 100000201190603337191863609201535272336.npz (256, 256) uint16

# %%
plt.imshow(img1, cmap="gray")
plt.title(files[1].name)
plt.show()

# %%
img2 = np.load(files[2])["data"]
print(files[2].name, img2.shape, img2.dtype)
# Out:
# 100001062780186333300160449315992055513.npz (256, 256) uint16

# %%
plt.imshow(img2, cmap="gray")
plt.title(files[2].name)
plt.show()

# %%
img3 = np.load(files[3])["data"]
print(files[3].name, img3.shape, img3.dtype)
# Out:
# 100001667933097808112506050500785212069.npz (256, 256) uint16

# %%
plt.imshow(img3, cmap="gray")
plt.title(files[3].name)
plt.show()

# %%
img4 = np.load(files[4])["data"]
print(files[4].name, img4.shape, img4.dtype)
# Out:
# 100002819211671685540712131744483029257.npz (256, 256) uint16

# %%
plt.imshow(img4, cmap="gray")
plt.title(files[4].name)
plt.show()

# %%
img5 = np.load(files[5])["data"]
print(files[5].name, img5.shape, img5.dtype)
# Out:
# 100002932790052970480170273042766799713.npz (256, 256) uint16

# %%
plt.imshow(img5, cmap="gray")
plt.title(files[5].name)
plt.show()

# %%
img6 = np.load(files[6])["data"]
print(files[6].name, img6.shape, img6.dtype)
# Out:
# 100003336946866979721439899673351190623.npz (256, 256) uint16

# %%
plt.imshow(img6, cmap="gray")
plt.title(files[6].name)
plt.show()

# %%
img7 = np.load(files[7])["data"]
print(files[7].name, img7.shape, img7.dtype)
# Out:
# 100003452723749999699495719100088159102.npz (256, 256) uint16

# %%
plt.imshow(img7, cmap="gray")
plt.title(files[7].name)
plt.show()

# %%
img8 = np.load(files[8])["data"]
print(files[8].name, img8.shape, img8.dtype)
# Out:
# 100004389276764272020424964671728412152.npz (256, 256) uint16

# %%
plt.imshow(img8, cmap="gray")
plt.title(files[8].name)
plt.show()

# %%
img9 = np.load(files[9])["data"]
print(files[9].name, img9.shape, img9.dtype)
# Out:
# 100004581092908878980242733221388780043.npz (256, 256) uint16

# %%
plt.imshow(img9, cmap="gray")
plt.title(files[9].name)
plt.show()

# %%
meta0 = json.load(open(META_DIR / (files[0].stem + ".json")))
meta0
# Out:
# {'PatientID': 'DHARD4DRTHSZ',
#  'View': 'cranio-caudal',
#  'WindowCenter': [2491.0, 2515.0, 2455.0],
#  'WindowWidth': [900.0, 750.0, 1050.0],
#  'WindowCenterWidthExplanation': ['NORMAL', 'HARDER', 'SOFTER'],
#  'ImagerPixelSpacing': [0.09409090909091, 0.09409090909091],
#  'ImageLaterality': 'R',
#  'coords': [244, 106, 255, 125],
#  'score': 0.03152620047330856,
#  'label': 'NonCancer'}
